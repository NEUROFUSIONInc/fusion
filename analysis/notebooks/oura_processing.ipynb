# %%
#reading oura file in
import json
import pandas as pd
import re
import numpy as np
# pd.set_option('max_columns', None)


oura_file = open('../data/oura_data_2022_04_16.json')
oura_json = oura_file.read()
oura_data = json.loads(oura_json)

# %%
#splitting oura_data into first dataframe which just has activity data. I will be combining it with other oura dataframes on the summary_date column as that column is in all dataframes
def prefix_columns(df, prefix):
    #get columns to replace
    columns_to_replace = {}
    for column in df.columns:
        # skip the summary_date join column
        if re.search('(summary_date)',column) != None:
            continue
        columns_to_replace[column] = f"{prefix}_{column}"
    
    return columns_to_replace

oura_activity = pd.DataFrame.from_records(oura_data["activity"])
oura_activity.rename(columns= prefix_columns(oura_activity, "activity"), inplace=True)
oura_activity
# Out:
#      activity_average_met  activity_cal_active  activity_cal_total  \
# 0                 0.93750                   23                1942
# 1                 1.34375                  234                2311
# 2                 1.34375                  290                2350
# 3                 1.15625                   96                2048
# 4                 1.68750                  707                2894
# ..                    ...                  ...                 ...
# 388               1.46875                  459                2506
# 389               1.50000                  457                2552
# 390               1.34375                  286                2298
# 391               1.75000                  795                2961
# 392               1.28125                  128                1939
#
#                                    activity_class_5min  \
# 0    0000000000000000000000000000000000000000000000...
# ...

# %%
#extracting restufl periods into it's own dataframe
oura_restful_periods = pd.DataFrame.from_records(oura_data["restful_periods"])
oura_restful_periods.rename(columns= prefix_columns(oura_restful_periods, "restful_period"), inplace=True)
oura_restful_periods
# Out:
#     restful_period_bedtime_end restful_period_bedtime_start  \
# 0    2021-01-21T13:02:49-08:00    2021-01-21T12:57:49-08:00
# 1    2021-01-21T13:23:46-08:00    2021-01-21T13:17:46-08:00
# 2    2021-01-23T13:02:44-08:00    2021-01-23T12:53:44-08:00
# 3    2021-01-23T13:25:29-08:00    2021-01-23T13:09:29-08:00
# 4    2021-01-23T14:50:29-08:00    2021-01-23T14:39:29-08:00
# ..                         ...                          ...
# 300  2022-04-11T14:27:59-07:00    2022-04-11T14:08:59-07:00
# 301  2022-04-12T12:31:01-07:00    2022-04-12T11:24:01-07:00
# 302  2022-04-12T14:59:01-07:00    2022-04-12T14:37:01-07:00
# 303  2022-04-12T15:38:00-07:00    2022-04-12T15:25:00-07:00
# 304  2022-04-12T16:52:01-07:00    2022-04-12T16:33:01-07:00
#
#      restful_period_breath_average  restful_period_duration  \
# 0                           15.250                      300
# 1                           15.250                      360
# 2                           15.125                      540
# ...

# %%
#extracting readiness into it's own dataframe

oura_readiness = pd.DataFrame.from_records(oura_data["readiness"])

oura_readiness.rename(columns = prefix_columns(oura_readiness, 'readiness'), inplace=True)
oura_readiness
# Out:
#      readiness_period_id  readiness_rest_mode_state  readiness_score  \
# 0                      0                          0               87
# 1                      1                          0               73
# 2                      1                          0               87
# 3                      2                          0               81
# 4                      0                          0               63
# ..                   ...                        ...              ...
# 324                    1                          0               49
# 325                    0                          0               51
# 326                    2                          0               43
# 327                    2                          0               71
# 328                    0                          0               49
#
#      readiness_score_previous_night  readiness_score_recovery_index  \
# 0                                71                             100
# ...

# %%
#extracting sleep into it's own dataframe

oura_sleep = pd.DataFrame.from_records(oura_data["sleep"])

oura_sleep.rename(columns = prefix_columns(oura_sleep, "sleep"), inplace=True)

oura_sleep
# Out:
#      sleep_awake          sleep_bedtime_end  sleep_bedtime_end_delta  \
# 0           4890  2021-01-21T03:41:29-08:00                    13289
# 1           3660  2021-01-22T05:30:24-08:00                    19824
# 2           7710  2021-01-23T08:25:02-08:00                    30302
# 3           3810  2021-01-24T05:54:01-08:00                    21241
# 4           5580  2021-01-27T05:40:39-08:00                    20439
# ..           ...                        ...                      ...
# 324         2520  2022-04-11T06:39:15-07:00                    23955
# 325         6150  2022-04-12T07:27:29-07:00                    26849
# 326         2010  2022-04-13T07:10:06-07:00                    25806
# 327         5160  2022-04-15T09:17:34-07:00                    33454
# 328         3720  2022-04-16T10:55:08-07:00                    39308
#
#            sleep_bedtime_start  sleep_bedtime_start_delta  \
# 0    2021-01-20T18:19:29-08:00                     -20431
# ...

# %% [markdown]
#  Get a combined dataset for oura data

# %%
# We merge activity, sleep & readiness..... because the nature of data will be one per day?
oura_daily_summary = oura_activity.merge(oura_sleep, on="summary_date", how="outer")

oura_daily_summary = oura_daily_summary.merge(oura_readiness, on="summary_date", how="outer")

oura_daily_summary

#TODO: Need to figure out how to factor in restful periods during the day 
#... maybe it can just be a summary on it's own
# Out:
#      activity_average_met  activity_cal_active  activity_cal_total  \
# 0                 0.93750                   23                1942
# 1                 1.34375                  234                2311
# 2                 1.34375                  290                2350
# 3                 1.15625                   96                2048
# 4                 1.68750                  707                2894
# ..                    ...                  ...                 ...
# 388               1.46875                  459                2506
# 389               1.50000                  457                2552
# 390               1.34375                  286                2298
# 391               1.75000                  795                2961
# 392               1.28125                  128                1939
#
#                                    activity_class_5min  \
# 0    0000000000000000000000000000000000000000000000...
# ...

# %%
#renaming columns with the correct unit of time
oura_daily_summary.rename(columns={"activity_inactive":"activity_inactive_minutes"}, inplace=True)
oura_daily_summary.rename(columns={"activity_non_wear":"activity_non_wear_minutes"}, inplace=True)
oura_daily_summary.rename(columns={"activity_rest":"activity_rest_minutes"}, inplace=True)
oura_daily_summary.rename(columns={"activity_low":"activity_low_minutes"}, inplace=True)
oura_daily_summary.rename(columns={"activity_medium":"activity_medium_minutes"}, inplace=True)
oura_daily_summary.rename(columns={"activity_high":"activity_high_minutes"}, inplace=True)
oura_daily_summary.rename(columns={"sleep_awake":"sleep_awake_seconds"}, inplace=True)
oura_daily_summary.rename(columns={"sleep_rem":"sleep_rem_seconds"}, inplace=True)
oura_daily_summary.rename(columns={"sleep_light":"sleep_light_seconds"}, inplace=True)
oura_daily_summary.rename(columns={"sleep_deep":"sleep_deep_seconds"}, inplace=True)
oura_daily_summary.rename(columns={"sleep_temperature_delta":"sleep_temperature_delta_celsius"}, inplace=True)
oura_daily_summary.rename(columns={"readiness_temperature_delta":"readiness_temperature_delta_celsius"}, inplace=True)
oura_daily_summary.rename(columns={"activity_cal_total":"activity_cal_total_kcal"}, inplace=True)

# %% [markdown]
# Going through the API documentation, it became apparent that the value '0' was often put in as a substitute for null. I will be changing these values to null.

# %%
# creating a function that changes the value 0 to null in places where 0 represents no available data

def replace_zero(column):
    for index in range(len(column)):
        if column[index] == 0:
            column[index] = np.nan

# %%
#replacing all zeros that are representative of null to null
# replace_zero(oura_daily_summary["score_recovery_time"])
# replace_zero(oura_daily_summary["score_training_volume"])
# replace_zero(oura_daily_summary["score_training_frequency"])
# replace_zero(oura_daily_summary["score_meet_daily_targets"])
# replace_zero(oura_daily_summary["score_move_every_hour"])
# replace_zero(oura_daily_summary["score_stay_active"])
# replace_zero(oura_daily_summary["score"])
# replace_zero(oura_daily_summary["score_total"])
# replace_zero(oura_daily_summary["score_rem"])
# replace_zero(oura_daily_summary["score_efficiency"])
# replace_zero(oura_daily_summary["score_deep"])
# replace_zero(oura_daily_summary["score_latency"])
# replace_zero(oura_daily_summary["score_disturbances"])
# replace_zero(oura_daily_summary["score_alignment"])

# %%
from datetime import datetime

oura_daily_summary.to_csv(f"../data/oura_daily_summary_{datetime.now().strftime('%Y_%m_%d')}.csv", index=False)

# %%
import requests 
url = 'https://api.ouraring.com/v2/usercollection/heartrate' 
params={ 
    'start_datetime': '2022-04-14T00:00:00-08:00', 
    'end_datetime': '2022-04-15T00:00:00-08:00' 
}
headers = { 
  'Authorization': 'Bearer NZDGAC4APTALZMRXO7FMBPPWNRIQDRE3' 
}
response = requests.request('GET', url, headers=headers, params=params) 
print(response.text)
# Out:
# {"data":[{"bpm":94,"source":"awake","timestamp":"2022-04-14T14:27:57+00:00"},{"bpm":90,"source":"awake","timestamp":"2022-04-14T14:28:22+00:00"},{"bpm":77,"source":"awake","timestamp":"2022-04-14T15:08:31+00:00"},{"bpm":71,"source":"awake","timestamp":"2022-04-14T15:09:07+00:00"},{"bpm":79,"source":"awake","timestamp":"2022-04-14T15:44:22+00:00"},{"bpm":69,"source":"awake","timestamp":"2022-04-14T15:44:24+00:00"},{"bpm":78,"source":"awake","timestamp":"2022-04-14T15:44:25+00:00"},{"bpm":71,"source":"awake","timestamp":"2022-04-14T15:49:39+00:00"},{"bpm":77,"source":"awake","timestamp":"2022-04-14T15:49:41+00:00"},{"bpm":74,"source":"awake","timestamp":"2022-04-14T15:49:47+00:00"},{"bpm":77,"source":"awake","timestamp":"2022-04-14T15:54:40+00:00"},{"bpm":72,"source":"awake","timestamp":"2022-04-14T15:54:48+00:00"},{"bpm":69,"source":"awake","timestamp":"2022-04-14T15:54:57+00:00"},{"bpm":90,"source":"awake","timestamp":"2022-04-14T15:59:31+00:00"},{"bpm":92,"source":"awake","timestamp
# ...
